# %%
import pandas as pd
import requests
import json
from config import api_key
import gmaps
df = pd.read_csv("../data/cleaned_data/cleaned_bank_loan_modeling_no_9307.csv")
df_Cali = pd.read_csv("../data/cleaned_data/California_Zip_Codes.csv")
df_Cali.head()
# Out:
#    ZIP Code       lat        lng         city state_id  state_name  zcta  \
# 0     90001  33.97365 -118.24904  Los Angeles       CA  California  True
# 1     90002  33.94906 -118.24679  Los Angeles       CA  California  True
# 2     90003  33.96409 -118.27368  Los Angeles       CA  California  True
# 3     90004  34.07624 -118.31101  Los Angeles       CA  California  True
# 4     90005  34.05939 -118.30909  Los Angeles       CA  California  True
#
#    parent_zcta  population  density  county_fips  county_name  county_weights  \
# 0          NaN     58974.0   6941.9         6037  Los Angeles  {"06037": 100}
# 1          NaN     53402.0   6890.0         6037  Los Angeles  {"06037": 100}
# 2          NaN     74117.0   7893.6         6037  Los Angeles  {"06037": 100}
# 3          NaN     61105.0   7733.4         6037  Los Angeles  {"06037": 100}
# 4          NaN     38885.0  12725.2         6037  Los Angeles  {"06037": 100}
#
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Years Work Experience', 'Income', 'ZIP Code', 'Family Size',
#        'Monthly Credit Card Spending', 'Education Level', 'Value of Mortgage',
#        'Personal Loan'],
#       dtype='object')

# %%
df_new_merge = df.merge(df_Cali,how = 'outer', on = ['ZIP Code'])
df_new_merge
# Out:
#        Age  Years Work Experience    Income  ZIP Code  Family Size  \
# 0     25.0                    1.0   49000.0     91107          4.0
# 1     30.0                    4.0   60000.0     91107          4.0
# 2     35.0                   10.0  200000.0     91107          2.0
# 3     54.0                   30.0   93000.0     91107          1.0
# 4     37.0                   12.0  169000.0     91107          2.0
# ...    ...                    ...       ...       ...          ...
# 6371   NaN                    NaN       NaN     96143          NaN
# 6372   NaN                    NaN       NaN     96146          NaN
# 6373   NaN                    NaN       NaN     96148          NaN
# 6374   NaN                    NaN       NaN     96155          NaN
# 6375   NaN                    NaN       NaN     96161          NaN
#
#       Monthly Credit Card Spending        Education Level  Value of Mortgage  \
# 0                           1600.0              Undergrad                0.0
# ...

# %%
df_new_merge.to_csv('Cleaned_ZipCodes.csv', index=False)
